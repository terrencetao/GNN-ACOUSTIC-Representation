# %%
matrix_dir = 'saved_matrix/yemba_command/fixed/'
embeddings_folder = 'saved_embeddings/yemba_command/fixed/knn/sub_units_5000/'

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Charger la matrice
matrix_with_labels = np.load(os.path.join(matrix_dir, f'filtered_matrix_with_labels_5000.npy'))

# Extraire les labels et la matrice de similarité
labels = matrix_with_labels[:, 0]  # Supposant que la première colonne contient les labels
similarity_matrix = matrix_with_labels[:, 1:]  # Le reste est la matrice de similarité

# Initialiser des listes pour stocker les similarités
same_label_similarities = []
diff_label_similarities = []

# Parcourir la matrice pour séparer les similarités selon les labels
for i in range(len(labels)):
    for j in range(i+1, len(labels)):  # Éviter de dupliquer les paires (par ex. (i, j) et (j, i))
        if labels[i] == labels[j]:
            same_label_similarities.append(similarity_matrix[i, j])  # Même label
        else:
            diff_label_similarities.append(similarity_matrix[i, j])  # Différent label

# Calculer les moyennes
mean_same_label = np.mean(same_label_similarities)
mean_diff_label = np.mean(diff_label_similarities)

# Afficher les résultats
print(f"Moyenne de similarité pour les éléments ayant le même label : {mean_same_label}")
print(f"Moyenne de similarité pour les éléments ayant des labels différents : {mean_diff_label}")

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(similarity_matrix, cmap="viridis", annot=False)
plt.title("Similarity Matrix Heatmap")
plt.xlabel("Labels")
plt.ylabel("Labels")
plt.show()
# Out:
# Moyenne de similarité pour les éléments ayant le même label : 0.9491882140709561
# Moyenne de similarité pour les éléments ayant des labels différents : -0.9979221183736785

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Load the matrix
matrix_with_labels = np.load(os.path.join(matrix_dir, f'similarity_matrix_with_labels_5000.npy'))

# Extract the labels and similarity matrix
labels = matrix_with_labels[:, 0]  # Assuming first column contains labels
similarity_matrix = matrix_with_labels[:, 1:]  # The rest is the similarity matrix

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(similarity_matrix,  cmap="viridis", annot=False)
plt.title("Similarity Matrix Heatmap")
plt.xlabel("Labels")
plt.ylabel("Labels")
plt.show()

# %%
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# Load the embeddings
embeddings = np.load(os.path.join(embeddings_folder, f'supervised_node_embeddings_5000.npy'))

# Compute the cosine similarity matrix
similarity_matrix = cosine_similarity(embeddings)

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(similarity_matrix, cmap='viridis')
plt.title("Cosine Similarity Matrix Heatmap")
plt.xlabel("Nodes")
plt.ylabel("Nodes")
plt.show()

# %%
similarity_matrix[0,260]
# Out:
# 0.99999994

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Load the embeddings
embeddings = np.load(os.path.join(embeddings_folder, f'supervised_node_embeddings_5000.npy'))

# Compute the cosine similarity matrix
similarity_matrix = cosine_similarity(embeddings)
#

# Initialiser des listes pour stocker les similarités
same_label_similarities = []
diff_label_similarities = []

# Parcourir la matrice pour séparer les similarités selon les labels
for i in range(len(labels)):
    for j in range(i+1, len(labels)):  # Éviter de dupliquer les paires (par ex. (i, j) et (j, i))
        if labels[i] == labels[j]:
            same_label_similarities.append(similarity_matrix[i, j])  # Même label
        else:
            diff_label_similarities.append(similarity_matrix[i, j])  # Différent label

# Calculer les moyennes
mean_same_label = np.mean(same_label_similarities)
mean_diff_label = np.mean(diff_label_similarities)

# Afficher les résultats
print(f"Moyenne de similarité pour les éléments ayant le même label : {mean_same_label}")
print(f"Moyenne de similarité pour les éléments ayant des labels différents : {mean_diff_label}")

# Créer des histogrammes
plt.figure(figsize=(12, 6))

# Histogramme des similarités avec le même label
plt.subplot(1, 2, 1)
plt.hist(same_label_similarities, bins=30, color='blue', alpha=0.7)
plt.title("Histogramme des similarités (même label)")
plt.xlabel("Similarité")
plt.ylabel("Fréquence")

# Histogramme des similarités avec des labels différents
plt.subplot(1, 2, 2)
plt.hist(diff_label_similarities, bins=30, color='orange', alpha=0.7)
plt.title("Histogramme des similarités (labels différents)")
plt.xlabel("Similarité")
plt.ylabel("Fréquence")

# Afficher les histogrammes
plt.tight_layout()
plt.show()
# Out:
# Moyenne de similarité pour les éléments ayant le même label : 0.998442530632019
# Moyenne de similarité pour les éléments ayant des labels différents : 0.9953818321228027

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Charger la matrice
embeddings_unsup = np.load(os.path.join(embeddings_folder, f'unsupervised_node_embeddings_5000.npy'))
# Compute the cosine similarity matrix
similarity_matrix_unsup = cosine_similarity(embeddings_unsup)
#

# Initialiser des listes pour stocker les similarités
same_label_similarities = []
diff_label_similarities = []

# Parcourir la matrice pour séparer les similarités selon les labels
for i in range(len(labels)):
    for j in range(i+1, len(labels)):  # Éviter de dupliquer les paires (par ex. (i, j) et (j, i))
        if labels[i] == labels[j]:
            same_label_similarities.append(similarity_matrix_unsup[i, j])  # Même label
        else:
            diff_label_similarities.append(similarity_matrix_unsup[i, j])  # Différent label

# Calculer les moyennes
mean_same_label = np.mean(same_label_similarities)
mean_diff_label = np.mean(diff_label_similarities)

# Afficher les résultats
print(f"Moyenne de similarité pour les éléments ayant le même label : {mean_same_label}")
print(f"Moyenne de similarité pour les éléments ayant des labels différents : {mean_diff_label}")

# Créer des histogrammes
plt.figure(figsize=(12, 6))

# Histogramme des similarités avec le même label
plt.subplot(1, 2, 1)
plt.hist(same_label_similarities, bins=30, color='blue', alpha=0.7)
plt.title("Histogramme des similarités (même label)")
plt.xlabel("Similarité")
plt.ylabel("Fréquence")

# Histogramme des similarités avec des labels différents
plt.subplot(1, 2, 2)
plt.hist(diff_label_similarities, bins=30, color='orange', alpha=0.7)
plt.title("Histogramme des similarités (labels différents)")
plt.xlabel("Similarité")
plt.ylabel("Fréquence")

# Afficher les histogrammes
plt.tight_layout()
plt.show()
# Out:
# Moyenne de similarité pour les éléments ayant le même label : 0.8087872266769409
# Moyenne de similarité pour les éléments ayant des labels différents : 0.14575135707855225

# %%
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# Load the embeddings
embeddings_unsup = np.load(os.path.join(embeddings_folder, f'unsupervised_node_embeddings_5000.npy'))

# Compute the cosine similarity matrix
similarity_matrix_unsup = cosine_similarity(embeddings_unsup)

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(similarity_matrix_unsup, cmap='viridis')
plt.title("Cosine Similarity Matrix Heatmap")
plt.xlabel("Nodes")
plt.ylabel("Nodes")
plt.show()

# %%
embeddings[0]
# Out:
# array([  47.682102 ,   90.226265 ,  -14.679754 ,   28.19854  ,
#         -93.74365  ,   36.903038 ,  -68.27886  ,   26.056156 ,
#         -89.001144 ,  -11.170048 ,    7.1741705,  166.05095  ,
#          85.06339  ,  -15.659565 , -111.269394 ,  -35.769146 ,
#          30.951412 ,  -77.15457  ,  -51.62623  , -105.70058  ,
#          24.822844 ,   -4.576721 ,  -42.123005 ,  -48.583313 ,
#        -127.38173  ,  -99.123505 ,  -66.899345 ,  -81.47417  ,
#         119.59068  ,  -26.146664 ,   61.66348  ,  -62.295113 ,
#          90.70215  ,   -5.1021233, -105.39703  ,  -37.73461  ,
#         -86.46663  ,   33.229187 ,  -27.349333 ,  -16.646572 ,
#          59.050842 ,   55.27134  ,   84.95032  ,   41.498398 ,
#         -55.87071  , -111.66663  ,   32.894714 ,   16.423367 ,
#          35.756283 , -114.621704 ,  -49.409904 ,   28.851772 ,
#          22.184328 ,   21.419123 ,   25.871998 ,   -9.793526 ,
#         -24.166708 ,  123.87462  ,  -81.090164 ,   -3.2297897,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Calculer la matrice de similarité cosinus
similarity_matrix = cosine_similarity(embeddings)

# Extraire les valeurs uniques (supérieures de la matrice de similarité)
similarity_values = similarity_matrix[np.triu_indices_from(similarity_matrix, k=1)]

# Tracer l'histogramme des similarités
plt.figure(figsize=(8, 6))
plt.hist(similarity_values, bins=50, color='blue', alpha=0.7)
plt.title('Distribution des similarités cosinus entre embeddings')
plt.xlabel('Cosine Similarity')
plt.ylabel('Fréquence')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Calculer la matrice de similarité cosinus
similarity_matrix_unsup = cosine_similarity(embeddings_unsup)

# Extraire les valeurs uniques (supérieures de la matrice de similarité)
similarity_values_unsup = similarity_matrix_unsup[np.triu_indices_from(similarity_matrix, k=1)]

# Tracer l'histogramme des similarités
plt.figure(figsize=(8, 6))
plt.hist(similarity_values_unsup, bins=50, color='blue', alpha=0.7)
plt.title('Distribution des similarités cosinus entre embeddings')
plt.xlabel('Cosine Similarity')
plt.ylabel('Fréquence')
plt.show()

# %%
from sklearn.manifold import TSNE

# Réduction des dimensions à 2D avec t-SNE
tsne = TSNE(n_components=2)
embeddings_2d_tsne = tsne.fit_transform(embeddings)

# Tracer les embeddings réduits avec t-SNE
plt.figure(figsize=(8, 6))
plt.scatter(embeddings_2d_tsne[:, 0], embeddings_2d_tsne[:, 1], c='blue', alpha=0.6)
plt.title('Visualisation des embeddings avec t-SNE')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.show()

# %%
len(label_names)
# Out:
# 60

# %%
from sklearn.manifold import TSNE

# Réduction des dimensions à 2D avec t-SNE
tsne = TSNE(n_components=2)
embeddings_2d_tsne_unsup = tsne.fit_transform(embeddings_unsup)

# Tracer les embeddings réduits avec t-SNE
plt.figure(figsize=(8, 6))
plt.scatter(embeddings_2d_tsne_unsup[:, 0], embeddings_2d_tsne_unsup[:, 1], c='blue', alpha=0.6)
plt.title('Visualisation des embeddings avec t-SNE')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.show()

# %%
len(np.unique(labels))
# Out:
# 19

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import pickle

# Charger les noms des labels depuis label_names.pkl
with open('label_names_yemba_command.pkl', 'rb') as f:
    label_names = pickle.load(f)

# Réduction des dimensions à 2D avec t-SNE
tsne = TSNE(n_components=2, perplexity=30, learning_rate=200, n_iter=1000, random_state=42)
embeddings_2d_tsne_unsup = tsne.fit_transform(embeddings_unsup)

unique_labels = np.unique(labels)
# Tracer les embeddings réduits avec t-SNE
plt.figure(figsize=(8, 6))

# Utilisation des labels pour colorier les points (assurez-vous d'avoir un array 'labels_unsup')
scatter = plt.scatter(embeddings_2d_tsne_unsup[:, 0], embeddings_2d_tsne_unsup[:, 1], c=labels, cmap='viridis', alpha=0.6)

# Ajouter une légende pour indiquer à quoi correspondent les couleurs avec les noms des labels
handles, _ = scatter.legend_elements()
#plt.legend(handles, [label_names[int(label)] for label in unique_labels], title="Labels")
# Ajouter une barre de couleur pour indiquer les différentes classes
plt.colorbar(scatter)

plt.title('Visualisation des embeddings avec t-SNE (coloré par label)')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.show()
